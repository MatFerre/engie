# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\utilisateur\Downloads\histo_gazpar_merged.csv.gz")

# %%
print(df.columns)
# Out:
# Index(['59343001', '01100723420098', '01100723420098.1', 'GD0991', '1M', 'RES',
#        'P011', '157', 'DGP', '1M.1', '0.0', '2024-07-03T00:00:00.000Z',
#        '0.2820719380273972', '0.2820719380273972.1', 'B2C-OM', '2024', '7',
#        '3', '2024-07-03T00:00:00.000Z.1', '2024-07-06T08:06:58.000Z',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', '59343001.1', '2024-07-03T00:00:00.000Z.2',
#        '15.730499999999996', '0.7695000000000043', '7.1', '3.1', '20.41',
#        '0.0.1', '152', '1'],
#       dtype='object')
